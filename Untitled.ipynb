# %%
import random
import pandas as pd
import numpy as np

female_names = [
    "Emma", "Olivia", "Ava", "Isabella", "Sophia", "Mia", "Charlotte", "Amelia",
    "Harper", "Evelyn", "Abigail", "Emily", "Elizabeth", "Sofia", "Avery", "Ella",
    "Scarlett", "Grace", "Chloe", "Victoria", "Aria", "Lily", "Luna", "Zoe",
    "Hannah", "Madison", "Riley", "Eleanor", "Ellie", "Penelope", "Layla", "Nora",
    "Hazel", "Aubrey", "Camila", "Aurora", "Violet", "Nova", "Zara", "Stella",
    "Maya", "Lucy", "Savannah", "Audrey", "Brooklyn", "Bella", "Claire", "Skylar",
    "Leah", "Samantha", "Liam", "Grace", "Zoey", "Aaliyah", "Ellie", "Paisley",
    "Hailey", "Elena", "Natalie", "Liliana", "Faith", "Gabriella", "Addison"
]
last_names = [
    "Smith", "Johnson", "Williams", "Brown", "Jones", "Miller", "Davis", "Garcia",
    "Rodriguez", "Martinez", "Hernandez", "Lopez", "Gonzalez", "Wilson", "Anderson",
    "Thomas", "Taylor", "Moore", "Jackson", "Martin", "Lee", "Perez", "Thompson",
    "White", "Harris", "Sanchez", "Clark", "Ramirez", "Lewis", "Robinson", "Walker",
    "Young", "Allen", "King", "Wright", "Scott", "Torres", "Nguyen", "Hill", "Adams",
    "Nelson", "Baker", "Hall", "Rivera", "Campbell", "Mitchell", "Carter", "Roberts",
    "Gomez", "Phillips", "Evans", "Turner", "Diaz", "Parker", "Cruz", "Edwards",
    "Collins", "Reyes", "Stewart", "Morris"
]
male_names = [
    "Liam", "Noah", "Ethan", "Oliver", "Aiden", "Muhammad", "Arjun", "Elijah",
    "William", "James", "Benjamin", "Lucas", "Mason", "Alexander", "Logan", "Daniel",
    "Michael", "Henry", "Jackson", "Sebastian", "Joseph", "David", "Matthew", "Samuel",
    "Carter", "Jayden", "John", "Owen", "Dylan", "Luke", "Gabriel", "Jack", "Nathan",
    "Isaac", "Eli", "Levi", "Andrew", "Ryan", "Anthony", "Christopher", "Charles",
    "Thomas", "Joshua", "Christian", "Hunter", "Connor", "Jonathan", "Aaron", "Caleb",
    "Ethan", "Nicholas", "Cameron", "Wyatt", "Jordan", "Jeremiah", "Colton", "Xavier",
    "Adrian", "Henry", "Leo"
]

def isim(cns):
    if cns=="E":
        return random.choice(male_names)
    if cns.upper()=="K":
        return random.choice(female_names)
def soyisim():
    return random.choice(last_names)

def tahmin(ssay):
    return random.randint(0,ssay)
ogrenciler={}
ogrenci={}
aln=["Say","Ea","Söz","Dil"]
alna=[30,50,10,10]


def ogrenci_Uret():
    i=0
    mtn,fzn,kmn,byn=0,0,0,0
    edn,tr1n,cg1n=0,0,0
    tr2n,cg2n,flsn,dnkn=0,0,0,0
    diln=0
    td=tahmin(40)
    ty=tahmin(40-td)
    tn=td-ty/4
    md=tahmin(40)
    my=tahmin(40-md)
    mn=md-my/4
    fd=tahmin(20)
    fy=tahmin(20-fd)
    fn=fd-fy/4
    sd=tahmin(20)
    sy=tahmin(20-sd)
    sn=sd-sy/4
    alan=random.choices(aln,weights=alna)[0]
    if alan=="Say":
        mtd=tahmin(40)
        mty=tahmin(40-mtd)
        mtn=mtd-mty/4
        
        fzd=tahmin(14)
        fzy=tahmin(14-fzd)
        fzn=mtd-mty/4
        
        kmd=tahmin(13)
        kmy=tahmin(13-kmd)
        kmn=kmd-kmy/4
        
        byd=tahmin(13)
        byy=tahmin(13-byd)
        byn=byd-byy/4
        
    if alan=="Ea":
        mtd=tahmin(40)
        mty=tahmin(40-mtd)
        mtn=mtd-mty/4
        
        edd=tahmin(24)
        edy=tahmin(24-edd)
        edn=edd-edy/4
        
        tr1d=tahmin(10)
        tr1y=tahmin(10-tr1d)
        tr1n=tr1d-tr1y/4
        
        cg1d=tahmin(6)
        cg1y=tahmin(6-cg1d)
        cg1n=cg1d-cg1y/4
    
    if alan=="Dil":
        dild=tahmin(80)
        dily=tahmin(80-dild)
        diln=dild-dily/4
    
    if alan=="Söz":
        
        edd=tahmin(24)
        edy=tahmin(24-edd)
        edn=edd-edy/4
        
        tr2d=tahmin(11)
        tr2y=tahmin(11-tr2d)
        tr2n=tr2d-tr2y/4
        
        cg2d=tahmin(11)
        cg2y=tahmin(11-cg1d)
        cg2n=cg1d-cg1y/4
        
        flsd=tahmin(12)
        flsy=tahmin(12-flsd)
        flsn=flsd-flsy/4
        
        dnkd=tahmin(6)
        dnky=tahmin(6-dnkd)
        dnkn=dnkd-dnky/4

    c=random.choice("EK")
    ogrenci = {
        "id": 1 + i,
        "sex": c,
        "name": isim(c),
        "surname": soyisim(),
        "Alan":alan,
        "AOB":random.randint(50,100),
        "trkD": td,
        "trkY": ty,
        "trkN": tn,
        "matD": md,
        "matY": my,
        "matN": mn,
        "fenD": fd,
        "fenY": fy,
        "fenN": fn,
        "sosD": sd,
        "sosY": sy,
        "sosN": sn,
        "Mt2N":mtn,
        "Fz2N":fzn,
        "Km2N":kmn,
        "By2N":byn,
        "EdbN":edn,
        "Tr1N":tr1n,
        "Cg1N":cg1n,
        "Tr2N":tr2n,
        "Cg2N":cg2n,
        "FlsN":flsn,
        "DnkN":dnkn,
        "DilN":diln
    }
    ogrenciler[1 + i] = ogrenci

for i in range(0,100000):
    ogrenci_Uret
    

df=pd.DataFrame(ogrenciler).T
print("Bitti")
# Out:
# Bitti

# %%
df["TopN"]=df["trkN"]+df["matN"]+df["fenN"]+df["sosN"]

df["TyT_Puan"]=df["trkN"]*3.3+df["matN"]*3.3+df["fenN"]*3.4+df["sosN"]*3.4+df["AOB"]*.6+100

df=df.sort_values(by="TyT_Puan",ascending=False)
df["Tyt_Sıra"] = range(1, len(df) + 1)
print("Tyt")
tytp=df["trkN"]*1.32+df["matN"]*1.32+df["fenN"]*1.36+df["sosN"]*1.36+100+df["AOB"]*.6

df["AYT_Say_Puan"]=tytp+df["Mt2N"]*3+df["Fz2N"]*2.85+df["By2N"]*3.07+df["Km2N"]*3.02
df=df.sort_values(by="AYT_Say_Puan",ascending=False)
df["AYT_Say_Sıra"] = range(1, len(df) + 1)
print("Tyt")
df["AYT_EA_Puan"]=tytp+df["Mt2N"]*3 + df["EdbN"]*3 +df["Tr1N"]*2.8+df["Cg1N"]*3.33
df=df.sort_values(by="AYT_EA_Puan",ascending=False)
df["AYT_EA_Sıra"] = range(1, len(df) + 1)

df["AYT_Söz_Puan"]=tytp+df["EdbN"]*3+df["Tr1N"]*2.8+df["Cg1N"]*3.33+df["Tr2N"]*2.91+df["Cg2N"]*2.91+df["FlsN"]*3+ df["DnkN"]*3.3
df=df.sort_values(by="AYT_Söz_Puan",ascending=False)
df["AYT_Söz_Sıra"] = range(1, len(df) + 1)

df["AYT_Dil_Puan"]=tytp+df["DilN"]*3

df=df.sort_values(by="AYT_Dil_Puan",ascending=False)
df["AYT_Dil_Sıra"] = range(1, len(df) + 1)

df.to_csv('ogrenci.csv', index=False)
print("tyt")
# Out:
# Tyt
# Tyt
# tyt

# %%
df_U=pd.read_csv("Tablo4.csv",encoding="utf-8",sep=';')
df_U["B.SIRASI"]=df_U["B.SIRASI"].replace("...",0)
df_U["B.SIRASI"]=df_U["B.SIRASI"].fillna(0)
df_U[df_U["B.SIRASI"]==np.NaN]
df_U["B.SIRASI"]=df_U["B.SIRASI"].astype("f")
df_U.sort_values(by="B.SIRASI",ascending=True)
# Out:
#              KODU                              ÜNİVERSİTE      ŞEHİR    TÜRÜ  \
# 5692  109310034.0                    ŞIRNAK ÜNİVERSİTESİ      ŞIRNAK  Devlet
# 5994  109890147.0                      UŞAK ÜNİVERSİTESİ        UŞAK  Devlet
# 5992  109830315.0                      UŞAK ÜNİVERSİTESİ        UŞAK  Devlet
# 5991  109810453.0                      UŞAK ÜNİVERSİTESİ        UŞAK  Devlet
# 5989  109890137.0                      UŞAK ÜNİVERSİTESİ        UŞAK  Devlet
# ...           ...                                     ...        ...     ...
# 2224  103610261.0  ERZİNCAN BİNALİ YILDIRIM ÜNİVERSİTESİ    ERZİNCAN  Devlet
# 3762  106490141.0                 KASTAMONU ÜNİVERSİTESİ   KASTAMONU  Devlet
# 5121  108690260.0                 PAMUKKALE ÜNİVERSİTESİ     DENİZLİ  Devlet
# 2270  103830103.0       ESKİŞEHİR OSMANGAZİ ÜNİVERSİTESİ   ESKİŞEHİR  Devlet
# 1623  102730301.0    ÇANAKKALE ONSEKİZ MART ÜNİVERSİTESİ   ÇANAKKALE  Devlet
#
#                                    FAKÜLTE  \
# 5692  İktisadi ve İdari Bilimler Fakültesi
# 5994              İslami İlimler Fakültesi
# 5992              İslami İlimler Fakültesi
# 5991              İslami İlimler Fakültesi
# 5989                    İletişim Fakültesi
# ...                                    ...
# 2224  İktisadi ve İdari Bilimler Fakültesi
# 3762           Sivil Havacılık Yüksekokulu
# 5121         Uygulamalı Bilimler Fakültesi
# 2270  İktisadi ve İdari Bilimler Fakültesi
# 1623   İnsan ve Toplum Bilimleri Fakültesi
#
#                                  PROGRAM  SÜRE  PAUNtÜRÜ  KONT  OBKONT.  MEB  \
# 5692                             İktisat      4       EA    20      1.0  NaN
# 5994      İslami İlimler (M.T.O.K.) (İÖ)      4      SÖZ    10      NaN  NaN
# 5992                 İslami İlimler (İÖ)      4      SÖZ    80      2.0  NaN
# 5991                      İslami İlimler      4      SÖZ   125      4.0  NaN
# 5989        Yeni Medya ve İletişim  (İÖ)      4      SÖZ    70      2.0  NaN
# ...                                  ...    ...      ...   ...      ...  ...
# 2224                       Sosyal Hizmet      4       EA    60      2.0  NaN
# 3762                  Havacılık Yönetimi      4       EA    60      2.0  NaN
# 5121    Uluslararası Ticaret ve Lojistik      4       EA    60      2.0  NaN
# 2270                        İktisat (İÖ)      4       EA    90      3.0  NaN
# 1623                      Sosyoloji (İÖ)      4       EA    40      1.0  NaN
#
#                  AÇIKLAMALAR  B.SIRASI       PUAN  P.DR.SAYI  D.DR.SAYI  \
# 5692                     NaN       0.0        NaN        2.0        1.0
# 5994  1, 3, 22, 24, 152, 153       0.0        NaN        NaN        NaN
# 5992       1, 3, 22, 24, 152       0.0        NaN        NaN        NaN
# 5991          1, 22, 24, 152       0.0        NaN        5.0        5.0
# 5989                       3       0.0        NaN        NaN        NaN
# ...                      ...       ...        ...        ...        ...
# 2224                       4  586587.0  202.76258        NaN        NaN
# 3762                   1, 10  586851.0  202.11123        NaN        NaN
# 5121                     NaN  586991.0  201.74012        NaN        NaN
# 2270                       3  587540.0  199.39256        NaN        NaN
# 1623                       3  587630.0  198.30730        NaN        NaN
#
#       DR.ÖĞR.ÜYE SAYI
# 5692              4.0
# 5994              NaN
# 5992              NaN
# 5991             12.0
# 5989              NaN
# ...               ...
# 2224              4.0
# 3762              NaN
# 5121              3.0
# 2270              NaN
# 1623              NaN
#
# [11385 rows x 17 columns]

# %%
a=df[["id","Alan","Tyt_Sıra","AYT_Say_Sıra","AYT_EA_Sıra","AYT_Söz_Sıra","AYT_Dil_Sıra"]].values.tolist()
c=0
tercih_df = pd.DataFrame()

for i in a:
    id=i[0]
    alan=i[1]
    tyt_sira=i[2]
    AYT_Say_Sıra=i[3]
    AYT_EA_Sıra=i[4]
    AYT_Söz_Sıra=i[5]
    AYT_Dil_Sıra=i[6]
    if alan=="Dil":
        bs=AYT_Dil_Sıra
    elif alan=="Söz":
        bs=AYT_Söz_Sıra
    elif alan=="Ea":
        bs=AYT_EA_Sıra
    else:
        bs=AYT_Say_Sıra
        
    if bs <=800: bs=800
    alt=bs*.9
    ust=bs*1.10
    if bs<=800:
        alt=1
        ust=bs
    
    b = df_U[(df_U["PAUNtÜRÜ"]==alan.upper())  & ((df_U["B.SIRASI"] >= alt) & (df_U["B.SIRASI"]<=ust))]
    #print(len(b),alt,ust,alan)
    if len(b)>0:
        if len(b)<24:
            n=len(b)
        else:
            n=random.randint(5,24)
        
        tercihler=b.sample(n)
        tercihler['Student_ID'] = id
        tercihler['Student_Alan'] = alan.upper()
        if alan=="Dil":
            tercihler['Sıra']=AYT_Dil_Sıra
        elif alan=="Söz":
            tercihler['Sıra']=AYT_Söz_Sıra
        elif alan=="Ea":
            tercihler['Sıra']=AYT_EA_Sıra
        else:
            tercihler['Sıra']=AYT_Say_Sıra
               
        tercihler["Tercih_Sıra"]=range(1,len(tercihler)+1)
                                
        tercih_df = pd.concat([tercih_df, tercihler], ignore_index=True)
        
tercih_df.to_csv(f'tercih.csv', index=False,sep=";")
tercih_df= tercih_df.sort_values(by=["Tercih_Sıra","KODU","B.SIRASI"],ascending=True)
tercih_df
# Out:
#               KODU                             ÜNİVERSİTE     ŞEHİR    TÜRÜ  \
# 64624  100110672.0  BOLU ABANT İZZET BAYSAL ÜNİVERSİTESİ       BOLU  Devlet
# 44820  100290069.0                 ADIYAMAN ÜNİVERSİTESİ   ADIYAMAN  Devlet
# 58744  100290069.0                 ADIYAMAN ÜNİVERSİTESİ   ADIYAMAN  Devlet
# 62558  100290069.0                 ADIYAMAN ÜNİVERSİTESİ   ADIYAMAN  Devlet
# 63910  100290069.0                 ADIYAMAN ÜNİVERSİTESİ   ADIYAMAN  Devlet
# ...            ...                                    ...       ...     ...
# 33178  207610354.0                   BİRUNİ ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 51077  207610354.0                   BİRUNİ ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 61180  207650947.0                   BİRUNİ ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 16847  209210050.0           ANKARA MEDİPOL ÜNİVERSİTESİ     ANKARA   VAKIF
# 63330  209210053.0           ANKARA MEDİPOL ÜNİVERSİTESİ     ANKARA   VAKIF
#
#                           FAKÜLTE                             PROGRAM  SÜRE   \
# 64624            Eğitim Fakültesi            Özel Eğitim Öğretmenliği      4
# 44820            Eğitim Fakültesi            Özel Eğitim Öğretmenliği      4
# 58744            Eğitim Fakültesi            Özel Eğitim Öğretmenliği      4
# 62558            Eğitim Fakültesi            Özel Eğitim Öğretmenliği      4
# 63910            Eğitim Fakültesi            Özel Eğitim Öğretmenliği      4
# ...                           ...                                 ...    ...
# 33178  Sağlık Bilimleri Fakültesi              Tıp Fakültesi (Burslu)      6
# 51077  Sağlık Bilimleri Fakültesi              Tıp Fakültesi (Burslu)      6
# 61180  Sağlık Bilimleri Fakültesi  Tıp Fakültesi (İngilizce) (Burslu)      6
# 16847  Siyasal Bilgiler Fakültesi  Tıp Fakültesi (İngilizce) (Burslu)      6
# 63330  Siyasal Bilgiler Fakültesi              Tıp Fakültesi (Burslu)      6
#
#       PAUNtÜRÜ  KONT  OBKONT.  ...                      AÇIKLAMALAR B.SIRASI  \
# 64624      SÖZ    60      2.0  ...                   1, 4, 150, 151  10379.0
# 44820      SÖZ    60      2.0  ...                      1, 150, 151   8359.0
# 58744      SÖZ    60      2.0  ...                      1, 150, 151   8359.0
# 62558      SÖZ    60      2.0  ...                      1, 150, 151   8359.0
# 63910      SÖZ    60      2.0  ...                      1, 150, 151   8359.0
# ...        ...   ...      ...  ...                              ...      ...
# 33178      SAY    15      NaN  ...              18, 21, 64, 79, 155   9160.0
# 51077      SAY    15      NaN  ...              18, 21, 64, 79, 155   9160.0
# 61180      SAY     9      NaN  ...  18, 21, 22, 23, 24, 64, 79, 155   8802.0
# 16847      SAY    12      NaN  ...  18, 21, 22, 23, 24, 64, 68, 155   8283.0
# 63330      SAY    12      NaN  ...              18, 21, 64, 68, 155   8369.0
#
#             PUAN P.DR.SAYI  D.DR.SAYI  DR.ÖĞR.ÜYE SAYI  Student_ID  \
# 64624  373.79536       3.0        3.0              3.0        6025
# 44820  379.08400       NaN        NaN              3.0        3465
# 58744  379.08400       NaN        NaN              3.0        3521
# 62558  379.08400       NaN        NaN              3.0        3525
# 63910  379.08400       NaN        NaN              3.0        7409
# ...          ...       ...        ...              ...         ...
# 33178  457.65479      50.0       15.0             43.0        5155
# 51077  457.65479      50.0       15.0             43.0        5053
# 61180  458.79871      50.0       15.0             43.0        4674
# 16847  460.44971       7.0        4.0             22.0        8378
# 63330  460.16975       7.0        4.0             22.0        3825
#
#        Student_Alan  Sıra  Tercih_Sıra
# 64624           SÖZ  9869            1
# 44820           SÖZ  8198            1
# 58744           SÖZ  9257            1
# 62558           SÖZ  8926            1
# 63910           SÖZ  7693            1
# ...             ...   ...          ...
# 33178           SAY  9198           23
# 51077           SAY  8355           23
# 61180           SAY  8365           23
# 16847           SAY  8410           23
# 63330           SAY  8212           23
#
# [64832 rows x 21 columns]

# %%
#tercih_df=tercih_df.sort_values(by=["Sıra","Tercih_Sıra"])
tercih_df=tercih_df.reset_index(drop=True)
tercih_df=tercih_df.drop(index=range(64827,len(tercih_df)))
tercih_df
# Out:
#               KODU                         ÜNİVERSİTE     ŞEHİR    TÜRÜ  \
# 0      203110035.0    İSTANBUL MEDİPOL ÜNİVERSİTESİ    İSTANBUL   VAKIF
# 1      203910309.0                  KOÇ ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 2      204890044.0              ÖZYEĞİN ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 3      102210223.0             BOĞAZİÇİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 4      202210329.0    İSTANBUL 29 MAYIS ÜNİVERSİTESİ   İSTANBUL   VAKIF
# ...            ...                                ...       ...     ...
# 64822  105510926.0      İSTANBUL TEKNİK ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64823  111091170.0     SAĞLIK BİLİMLERİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64824  111091397.0     SAĞLIK BİLİMLERİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64825  102210126.0             BOĞAZİÇİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64826  105710015.0  İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ       İZMİR  Devlet
#
#                                     FAKÜLTE  \
# 0              Sağlık Bilimleri Yüksekokulu
# 1      İktisadi ve İdari Bilimler Fakültesi
# 2             Mimarlık ve Tasarım Fakültesi
# 3      İktisadi ve İdari Bilimler Fakültesi
# 4                        İlahiyat Fakültesi
# ...                                     ...
# 64822      Uçak ve Uzay Bilimleri Fakültesi
# 64823    Hamidiye Yaşam Bilimleri Fakültesi
# 64824    Hamidiye Yaşam Bilimleri Fakültesi
# 64825                Fen-Edebiyat Fakültesi
# 64826                 Su Ürünleri Fakültesi
#
#                                            PROGRAM SÜRE  PAUNtÜRÜ KONT  \
# 0                           Tıp Fakültesi (Burslu)     6      SAY   21
# 1                     İşletme (İngilizce) (Burslu)     4       EA   24
# 2        İletişim ve Tasarımı (İngilizce) (Burslu)     4      SÖZ    5
# 3                              İşletme (İngilizce)     4       EA  100
# 4                                İlahiyat (Burslu)     4      SÖZ    8
# ...                                            ...   ...      ...  ...
# 64822                Uzay Mühendisliği (İngilizce)     4      SAY   60
# 64823          Hamidiye Uluslararası Tıp Fakültesi     6      SAY   60
# 64824                          İzmir Tıp Fakültesi     6      SAY   60
# 64825                            Fizik (İngilizce)     4      SAY   65
# 64826                                Tıp Fakültesi     6      SAY  200
#
#       OBKONT.  ...       PUAN P.DR.SAYI D.DR.SAYI DR.ÖĞR.ÜYE SAYI Student_ID  \
# 0         NaN  ...  514.65882      97.0      42.0            96.0       8041
# 1         NaN  ...  476.54722      10.0       5.0            11.0        529
# 2         NaN  ...  442.52335       NaN       NaN             5.0       8875
# 3         3.0  ...  465.13704       9.0       5.0             6.0        529
# 4         NaN  ...  512.30958       6.0       2.0             4.0       8875
# ...       ...  ...        ...       ...       ...             ...        ...
# 64822     2.0  ...  454.29643       7.0       2.0             3.0       5113
# 64823     2.0  ...  454.15266       1.0       2.0            12.0       5113
# 64824     2.0  ...  453.92302       NaN       NaN             NaN       5113
# 64825     2.0  ...  453.57520      12.0       2.0             6.0       5113
# 64826     5.0  ...  455.83382      83.0      52.0            56.0       5113
#
#       Student_Alan  Sıra Tercih_Sıra durum sayı
# 0              SAY     1           1          0
# 1               EA     1           1          0
# 2              SÖZ     1           1          0
# 3               EA     1           2          0
# 4              SÖZ     1           2          0
# ...            ...   ...         ...   ...  ...
# 64822          SAY  9997          14          0
# 64823          SAY  9997          15          0
# 64824          SAY  9997          16          0
# 64825          SAY  9997          17          0
# 64826          SAY  9997          18          0
#
# [64827 rows x 23 columns]

# %%
tercih_df["durum"]=""
tercih_df["sayı"]=0
df_t=tercih_df.copy()

print(df_t["KODU"].isna().count())
df_t["KODU"]=df_t["KODU"].astype("string")
df_t["KODU"]=df_t["KODU"].str.replace(".0","")
df_t["KODU"].fillna(0)
# Out:
# 64827
# 0        203110035
# 1        203910309
# 2        204890044
# 3        102210223
# 4        202210329
#            ...
# 64822    105510926
# 64823    111091170
# 64824    111091397
# 64825    102210126
# 64826    105710015
# Name: KODU, Length: 64827, dtype: string

# %%
df_t
# Out:
#             KODU                         ÜNİVERSİTE     ŞEHİR    TÜRÜ  \
# 0      203110035    İSTANBUL MEDİPOL ÜNİVERSİTESİ    İSTANBUL   VAKIF
# 1      203910309                  KOÇ ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 2      204890044              ÖZYEĞİN ÜNİVERSİTESİ   İSTANBUL   VAKIF
# 3      102210223             BOĞAZİÇİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 4      202210329    İSTANBUL 29 MAYIS ÜNİVERSİTESİ   İSTANBUL   VAKIF
# ...          ...                                ...       ...     ...
# 64822  105510926      İSTANBUL TEKNİK ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64823  111091170     SAĞLIK BİLİMLERİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64824  111091397     SAĞLIK BİLİMLERİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64825  102210126             BOĞAZİÇİ ÜNİVERSİTESİ   İSTANBUL  Devlet
# 64826  105710015  İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ       İZMİR  Devlet
#
#                                     FAKÜLTE  \
# 0              Sağlık Bilimleri Yüksekokulu
# 1      İktisadi ve İdari Bilimler Fakültesi
# 2             Mimarlık ve Tasarım Fakültesi
# 3      İktisadi ve İdari Bilimler Fakültesi
# 4                        İlahiyat Fakültesi
# ...                                     ...
# 64822      Uçak ve Uzay Bilimleri Fakültesi
# 64823    Hamidiye Yaşam Bilimleri Fakültesi
# 64824    Hamidiye Yaşam Bilimleri Fakültesi
# 64825                Fen-Edebiyat Fakültesi
# 64826                 Su Ürünleri Fakültesi
#
#                                            PROGRAM SÜRE  PAUNtÜRÜ KONT  \
# 0                           Tıp Fakültesi (Burslu)     6      SAY   21
# 1                     İşletme (İngilizce) (Burslu)     4       EA   24
# 2        İletişim ve Tasarımı (İngilizce) (Burslu)     4      SÖZ    5
# 3                              İşletme (İngilizce)     4       EA  100
# 4                                İlahiyat (Burslu)     4      SÖZ    8
# ...                                            ...   ...      ...  ...
# 64822                Uzay Mühendisliği (İngilizce)     4      SAY   60
# 64823          Hamidiye Uluslararası Tıp Fakültesi     6      SAY   60
# 64824                          İzmir Tıp Fakültesi     6      SAY   60
# 64825                            Fizik (İngilizce)     4      SAY   65
# 64826                                Tıp Fakültesi     6      SAY  200
#
#       OBKONT.  ...       PUAN P.DR.SAYI D.DR.SAYI DR.ÖĞR.ÜYE SAYI Student_ID  \
# 0         NaN  ...  514.65882      97.0      42.0            96.0       8041
# 1         NaN  ...  476.54722      10.0       5.0            11.0        529
# 2         NaN  ...  442.52335       NaN       NaN             5.0       8875
# 3         3.0  ...  465.13704       9.0       5.0             6.0        529
# 4         NaN  ...  512.30958       6.0       2.0             4.0       8875
# ...       ...  ...        ...       ...       ...             ...        ...
# 64822     2.0  ...  454.29643       7.0       2.0             3.0       5113
# 64823     2.0  ...  454.15266       1.0       2.0            12.0       5113
# 64824     2.0  ...  453.92302       NaN       NaN             NaN       5113
# 64825     2.0  ...  453.57520      12.0       2.0             6.0       5113
# 64826     5.0  ...  455.83382      83.0      52.0            56.0       5113
#
#       Student_Alan  Sıra Tercih_Sıra durum sayı
# 0              SAY     1           1          0
# 1               EA     1           1          0
# 2              SÖZ     1           1          0
# 3               EA     1           2          0
# 4              SÖZ     1           2          0
# ...            ...   ...         ...   ...  ...
# 64822          SAY  9997          14          0
# 64823          SAY  9997          15          0
# 64824          SAY  9997          16          0
# 64825          SAY  9997          17          0
# 64826          SAY  9997          18          0
#
# [64827 rows x 23 columns]

# %%
df_t["KONT"]=df_t["KONT"].replace(" ","")
df_t["KONT"]=df_t["KONT"].astype("string")

# %%
kodlar = df_t["KODU"].unique()

for kod in kodlar:
    trc = df_t[df_t["KODU"] == kod]
    
    if len(trc)>0:
        kont=int(trc.iloc[0,8])
        unv=trc.iloc[0,1]
        bolum=trc.iloc[0,5]
        
    if kont==0:
        print(trc)
    trc=trc.head(kont+1)
       
    trc_indexes = trc.index
    yer=0
    for j, index in enumerate(trc_indexes):
        
        if j<int(kont):
            student_id = trc.loc[index, "Student_ID"]
            df_t.loc[(df_t["KODU"] == kod) & (df_t["Student_ID"] == student_id), "durum"] = "Yerleşti"
            df_t.loc[(df_t["KODU"] == kod) & (df_t["Student_ID"] == student_id), "sayı"] = j + 1
            rows_to_drop = df_t[(df_t["Student_ID"] == student_id) & (df_t["durum"] != "Yerleşti")].index
            df_t = df_t.drop(index=rows_to_drop)
            yer=j
            
        else:
            yer=j
            break
    print(f"Bölüm Kodu:{kod},{unv.strip()},{bolum.strip()}\nBaşvuru Sayısı:{len(trc)},Kontenjan:{kont},Yerleşen:{yer}")
    
print(df_t)
# Out:
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:203110035,İSTANBUL MEDİPOL ÜNİVERSİTESİ,Tıp Fakültesi (Burslu)
# Başvuru Sayısı:22,Kontenjan:21,Yerleşen:21
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:203910309,KOÇ ÜNİVERSİTESİ,İşletme (İngilizce) (Burslu)
# Başvuru Sayısı:25,Kontenjan:24,Yerleşen:24
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:204890044,ÖZYEĞİN ÜNİVERSİTESİ,İletişim ve Tasarımı (İngilizce) (Burslu)
# Başvuru Sayısı:6,Kontenjan:5,Yerleşen:5
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:202210329,İSTANBUL 29 MAYIS ÜNİVERSİTESİ,İlahiyat (Burslu)
# Başvuru Sayısı:9,Kontenjan:8,Yerleşen:8
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:102210198,BOĞAZİÇİ ÜNİVERSİTESİ,Tarih (İngilizce)
# Başvuru Sayısı:71,Kontenjan:70,Yerleşen:70
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:203910115,KOÇ ÜNİVERSİTESİ,Matematik (İngilizce) (Burslu)
# Başvuru Sayısı:5,Kontenjan:4,Yerleşen:4
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Bölüm Kodu:102210223,BOĞAZİÇİ ÜNİVERSİTESİ,İşletme (İngilizce)
# Başvuru Sayısı:101,Kontenjan:100,Yerleşen:100
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([854, 855, 857, 862, 864, 865, 868, 869, 871, 873, 875], dtype='int64')
# Index([878, 883, 885, 887, 890, 895, 900, 903, 906, 907, 910], dtype='int64')
# Index([914, 916, 918, 921, 924, 927, 930, 934, 940, 942, 943], dtype='int64')
# Index([946, 950, 952, 958, 961, 966, 967, 972, 974, 976, 978], dtype='int64')
# Index([980, 983, 988, 989, 993, 997, 999, 1002, 1005, 1007, 1009], dtype='int64')
# Index([1015, 1017, 1018, 1021, 1022, 1024, 1027, 1030, 1033, 1034, 1037], dtype='int64')
# Index([1039, 1042, 1046, 1049, 1052, 1055, 1059, 1060, 1063, 1069, 1071], dtype='int64')
# Index([1075, 1078, 1080, 1082, 1084, 1086, 1088, 1089, 1091, 1093, 1095], dtype='int64')
# Index([1099, 1102, 1105, 1108, 1110, 1114, 1116, 1122, 1125, 1127, 1130], dtype='int64')
# Index([1132, 1135, 1139, 1141, 1146, 1147, 1152, 1154, 1158, 1160, 1163], dtype='int64')
# Index([1166, 1169, 1172, 1176, 1179, 1181, 1184, 1187, 1191, 1194, 1198], dtype='int64')
# Index([1201, 1205, 1207, 1211, 1217, 1218, 1222, 1224, 1227, 1229, 1231], dtype='int64')
# Index([1235, 1237, 1242, 1245, 1248, 1249, 1253, 1259, 1261, 1263, 1265], dtype='int64')
# Index([1268, 1271, 1273, 1274, 1278, 1280, 1282, 1284, 1287, 1288, 1290], dtype='int64')
# Index([1294, 1297, 1300, 1303, 1305, 1309, 1311, 1316, 1317, 1320, 1323], dtype='int64')
# Index([1327, 1334, 1338, 1339, 1343, 1346, 1349, 1351, 1355, 1356, 1359], dtype='int64')
# Index([1361, 1365, 1367, 1370, 1374, 1379, 1382, 1386, 1389, 1391, 1393], dtype='int64')
# Index([1396, 1397, 1400, 1401, 1403, 1407, 1409, 1412, 1414, 1416, 1417], dtype='int64')
# Index([1421, 1427, 1430, 1432, 1435, 1439, 1442, 1445, 1448, 1450, 1452], dtype='int64')
# Index([1455, 1457, 1462, 1464, 1466, 1469, 1473, 1475, 1479, 1482, 1484], dtype='int64')
# Index([1489, 1492, 1494, 1497, 1501, 1503, 1508, 1510, 1512, 1515, 1520], dtype='int64')
# Index([1525, 1530, 1532, 1535, 1538, 1540, 1545, 1546, 1550, 1552, 1553], dtype='int64')
# Index([1556, 1558, 1560, 1563, 1565, 1566, 1570, 1572, 1574, 1577, 1579], dtype='int64')
# Index([1581, 1584, 1587, 1592, 1594, 1596, 1601, 1603, 1605, 1609, 1613], dtype='int64')
# Index([1615, 1618, 1619, 1621, 1623, 1625, 1627, 1629, 1632, 1634, 1636], dtype='int64')
# Index([1641, 1644, 1647, 1649, 1653, 1657, 1660, 1662, 1664, 1668, 1669], dtype='int64')
# Index([1674, 1676, 1679, 1680, 1682, 1686, 1689, 1691, 1692, 1695, 1696], dtype='int64')
# Index([1699, 1701, 1703, 1707, 1709, 1711, 1714, 1716, 1718, 1720, 1721], dtype='int64')
# Index([1724, 1727, 1731, 1733, 1736, 1739, 1742, 1745, 1750, 1752, 1755], dtype='int64')
# Index([1761, 1763, 1764, 1766, 1769, 1770, 1773, 1775, 1776, 1779, 1780], dtype='int64')
# Index([1783, 1787, 1789, 1792, 1797, 1798, 1806, 1809, 1811, 1813, 1815], dtype='int64')
# Index([1817, 1820, 1823, 1828, 1830, 1833, 1837, 1840, 1844, 1847, 1848], dtype='int64')
# Index([1855, 1858, 1862, 1865, 1866, 1869, 1873, 1876, 1878, 1881, 1882], dtype='int64')
# Index([1885, 1887, 1890, 1891, 1894, 1896, 1898, 1902, 1904, 1906, 1907], dtype='int64')
# Index([1911, 1913, 1916, 1920, 1923, 1925, 1929, 1932, 1935, 1940, 1941], dtype='int64')
# Index([1945, 1946, 1948, 1951, 1953, 1955, 1956, 1959, 1961, 1962, 1964], dtype='int64')
# Index([1969, 1971, 1973, 1976, 1978, 1980, 1981, 1984, 1985, 1987, 1991], dtype='int64')
# Index([1994, 1997, 1999, 2003, 2004, 2006, 2008, 2011, 2013, 2014, 2017], dtype='int64')
# Index([2020, 2024, 2028, 2032, 2035, 2038, 2042, 2044, 2046, 2049, 2050], dtype='int64')
# Index([2053, 2057, 2061, 2063, 2065, 2068, 2072, 2076, 2078, 2081, 2082], dtype='int64')
# Index([2092, 2094, 2096, 2100, 2103, 2106, 2108, 2111, 2115, 2116, 2118], dtype='int64')
# Index([2122, 2124, 2126, 2127, 2130, 2131, 2134, 2137, 2140, 2142, 2144], dtype='int64')
# Bölüm Kodu:202110408,İHSAN DOĞRAMACI BİLKENT ÜNİVERSİTESİ,Bilgisayar Mühendisliği (İngilizce) (Burslu)
# Başvuru Sayısı:46,Kontenjan:45,Yerleşen:45
# Index([2146, 2150, 2152, 2155, 2158, 2161, 2165, 2168, 2171, 2176, 2178], dtype='int64')
# Index([2180, 2183, 2184, 2186, 2188, 2191, 2192, 2194, 2199, 2201, 2202], dtype='int64')
# Index([2206, 2208, 2213, 2214, 2219, 2222, 2223, 2227, 2229, 2233, 2235], dtype='int64')
# Index([2239, 2242, 2243, 2248, 2249, 2252, 2253, 2255, 2257, 2259, 2262], dtype='int64')
# Index([2264, 2266, 2269, 2271, 2272, 2274, 2278, 2280, 2283, 2284, 2287], dtype='int64')
# Index([2289, 2293, 2296, 2299, 2302, 2308, 2310, 2313, 2317, 2318, 2320], dtype='int64')
# Index([2323, 2326, 2328, 2329, 2332, 2334, 2338, 2339, 2342, 2344, 2346], dtype='int64')
# Index([2348, 2352, 2356, 2358, 2363, 2366, 2370, 2372, 2376, 2377, 2380], dtype='int64')
# Index([2384, 2387, 2388, 2390, 2393, 2395, 2396, 2398, 2401, 2402, 2404], dtype='int64')
# Index([2411, 2414, 2416, 2419, 2422, 2426, 2429, 2432, 2434, 2436, 2439], dtype='int64')
# Index([2441, 2444, 2445, 2447, 2450, 2451, 2454, 2456, 2458, 2459, 2461], dtype='int64')
# Index([2466, 2468, 2471, 2472, 2475, 2477, 2480, 2483, 2485, 2486, 2488], dtype='int64')
# Index([2492, 2493, 2496, 2499, 2502, 2503, 2506, 2507, 2510, 2511, 2514], dtype='int64')
# Index([2516, 2520, 2523, 2525, 2528, 2532, 2537, 2541, 2543, 2546, 2547], dtype='int64')
# Index([2550, 2553, 2555, 2556, 2558, 2560, 2563, 2565, 2566, 2570, 2573], dtype='int64')
# Index([2575, 2578, 2583, 2585, 2587, 2590, 2594, 2600, 2602, 2604, 2606], dtype='int64')
# Bölüm Kodu:203910424,KOÇ ÜNİVERSİTESİ,Endüstri Mühendisliği (İngilizce) (Burslu)
# Başvuru Sayısı:17,Kontenjan:16,Yerleşen:16
# Index([2609, 2612, 2616, 2619, 2622, 2626, 2627, 2631, 2635, 2637, 2640], dtype='int64')
# Index([2644, 2648, 2650, 2652, 2655, 2660, 2662, 2668, 2671, 2672, 2674], dtype='int64')
# Index([2677, 2680, 2681, 2684, 2688, 2689, 2692, 2693, 2696, 2697, 2700], dtype='int64')
# Index([2703, 2704, 2706, 2708, 2711, 2712, 2717, 2719, 2720, 2723, 2724], dtype='int64')
# Index([2727, 2730, 2731, 2734, 2735, 2738, 2740, 2741, 2743, 2745, 2747], dtype='int64')
# Index([2753, 2755, 2756, 2759, 2760, 2764, 2767, 2769, 2771, 2772, 2774], dtype='int64')
# Index([2778, 2780, 2782, 2783, 2785, 2788, 2790, 2791, 2793, 2796, 2797], dtype='int64')
# Index([2802, 2805, 2810, 2812, 2815, 2821, 2823, 2826, 2829, 2832, 2834], dtype='int64')
# Index([2837, 2841, 2842, 2845, 2847, 2848, 2850, 2853, 2855, 2856, 2858], dtype='int64')
# Index([2862, 2865, 2868, 2870, 2872, 2873, 2876, 2878, 2879, 2882, 2884], dtype='int64')
# Index([2886, 2890, 2892, 2897, 2899, 2905, 2908, 2911, 2914, 2915, 2918], dtype='int64')
# Index([2922, 2924, 2928, 2933, 2937, 2939, 2942, 2944, 2948, 2949, 2952], dtype='int64')
# Index([2954, 2956, 2958, 2961, 2962, 2965, 2967, 2969, 2970, 2973, 2977], dtype='int64')
# Index([2980, 2981, 2984, 2986, 2989, 2992, 2993, 2995, 2998, 3000, 3001], dtype='int64')
# Index([3005, 3008, 3010, 3012, 3014, 3017, 3019, 3021, 3022, 3025, 3027], dtype='int64')
# Index([3029, 3032, 3035, 3039, 3042, 3045, 3048, 3051, 3057, 3058, 3061], dtype='int64')
# Index([3063, 3066, 3068, 3070, 3072, 3073, 3075, 3077, 3082, 3083, 3086], dtype='int64')
# Index([3089, 3090, 3092, 3095, 3096, 3098, 3100, 3102, 3104, 3107, 3109], dtype='int64')
# Index([3113, 3116, 3118, 3119, 3121, 3123, 3126, 3127, 3131, 3134, 3136], dtype='int64')
# Index([3139, 3140, 3143, 3146, 3149, 3150, 3153, 3155, 3157, 3158, 3160], dtype='int64')
# Index([3163, 3166, 3168, 3170, 3171, 3173, 3176, 3178, 3181, 3184, 3186], dtype='int64')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[215], line 25
#      23     rows_to_drop = df_t[(df_t["Student_ID"] == student_id) & (df_t["durum"] != "Yerleşti")].index
#      24     print(rows_to_drop)
# ---> 25     df_t = df_t.drop(index=rows_to_drop)
#      26     yer=j
#      28 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:4630, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4627     new_axis = axis.take(indexer)
#    4629 bm_axis = self.ndim - axis_num - 1
# -> 4630 new_mgr = self._mgr.reindex_indexer(
#    4631     new_axis,
#    4632     indexer,
#    4633     axis=bm_axis,
#    4634     allow_dups=True,
#    4635     copy=None,
#    4636     only_slice=only_slice,
#    4637 )
#    4638 result = self._constructor(new_mgr)
#    4639 if self.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:747, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
# --> 747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:748, in <listcomp>(.0)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
# --> 748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\blocks.py:960, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     957 if new_mgr_locs is None:
#     958     new_mgr_locs = self._mgr_locs
# --> 960 if not is_dtype_equal(new_values.dtype, self.dtype):
#     961     return self.make_block(new_values, new_mgr_locs)
#     962 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\dtypes\common.py:551, in is_dtype_equal(source, target)
#     546             return False
#     548     return _is_dtype(arr_or_dtype, condition)
# --> 551 def is_dtype_equal(source, target) -> bool:
#     552     """
#     553     Check if two dtypes are equal.
#     554
#    (...)
#     576     False
#     577     """
#     578     if isinstance(target, str):
#
# KeyboardInterrupt:

# %%
a=df_t.groupby(["FAKÜLTE","PROGRAM"])["PROGRAM"].count()
b=df_t.groupby(["FAKÜLTE","PROGRAM"])["KONT"].unique()
#print(a,b)
df_t.groupby("Student_ID")["Student_ID"].count()
df_t.groupby("durum")["durum"].count()
#df_t[df_t["durum"]!="Yerleşti"]
# Out:
# durum
#             18070
# Yerleşti     6034
# Name: durum, dtype: int64

# %%
kod=df_t.loc[0,"KODU"]
kon=df_t.loc[0,"KONT"]
trc=df_t[df_t["KODU"] == kod]
for j in range(0,len(trc)):
    kod1=df_t.loc[0,"KODU"]
    id=trc.loc[j,"Student_ID"]
    df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["durum"]="Yerleşti"
    df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["sayı"]=j+1
    
trc
# Out:
# C:\Users\halil\AppData\Local\Temp\ipykernel_14928\1492642584.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["durum"]="Yerleşti"
# C:\Users\halil\AppData\Local\Temp\ipykernel_14928\1492642584.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["sayı"]=j+1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 6
#       4 for j in range(0,len(trc)):
#       5     kod1=df_t.loc[0,"KODU"]
# ----> 6     id=trc.loc[j,"Student_ID"]
#       7     df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["durum"]="Yerleşti"
#       8     df_t[(df_t["KODU"]==kod1) & (df_t["Student_ID"]==id)]["sayı"]=j+1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3877, in DataFrame._get_value(self, index, col, takeable)
#    3871 engine = self.index._engine
#    3873 if not isinstance(self.index, MultiIndex):
#    3874     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3875     #  results if our categories are integers that dont match our codes
#    3876     # IntervalIndex: IntervalTree has no get_loc
# -> 3877     row = self.index.get_loc(index)
#    3878     return series._values[row]
#    3880 # For MultiIndex going through engine effectively restricts us to
#    3881 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 1

# %%
df_t.loc[0,"sayı"]=4

# %%
df_t.loc[1,"sayı"]
# Out:
# 4

# %%
df_t.loc[df_t.groupby("Student_ID")["Student_ID"].count()>1,"Student_ID"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df_t.loc[df_t.groupby("Student_ID")["Student_ID"].count()>1,"Student_ID"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1289, in _LocIndexer._getitem_tuple(self, tup)
#    1286 if self._multi_take_opportunity(tup):
#    1287     return self._multi_take(tup)
# -> 1289 return self._getitem_tuple_same_dim(tup)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:955, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     952 if com.is_null_slice(key):
#     953     continue
# --> 955 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     956 # We should never have retval.ndim < self.ndim, as that should
#     957 #  be handled by the _getitem_lowerdim call above.
#     958 assert retval.ndim == self.ndim
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1325, in _LocIndexer._getitem_axis(self, key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
#    1324 elif com.is_bool_indexer(key):
# -> 1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#    1328     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1121, in _LocationIndexer._getbool_axis(self, key, axis)
#    1117 @final
#    1118 def _getbool_axis(self, key, axis: AxisInt):
#    1119     # caller is responsible for ensuring non-None axis
#    1120     labels = self.obj._get_axis(axis)
# -> 1121     key = check_bool_indexer(labels, key)
#    1122     inds = key.nonzero()[0]
#    1123     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:2506, in check_bool_indexer(index, key)
#    2504 indexer = result.index.get_indexer_for(index)
#    2505 if -1 in indexer:
# -> 2506     raise IndexingError(
#    2507         "Unalignable boolean Series provided as "
#    2508         "indexer (index of the boolean Series and of "
#    2509         "the indexed object do not match)."
#    2510     )
#    2512 result = result.take(indexer)
#    2514 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
# AYT_Say_Sıra,,AYT_EA_Sıra,AYT_Söz_Sıra,AYT_Dil_Sıra

# %%
tercih_df

# %%
tercih_df["durum"]="Kayıtlı"
tercih_df["sayı"]=0
tercih_df#[["KODU","ÜNİVERSİTE","ŞEHİR","TÜRÜ","FAKÜLTE","PROGRAM","SÜRE","PAUNtÜRÜ","KONT.","OBKONT.","Student_ID","Student_Alan","Student_AYT_Say_Sıra","Student_AYT_EA_Sıra","Student_AYT_Söz_Sıra","Student_AYT_Dil_Sıra","Tercih_Sıra","durum"]]
for index, row in tercih_df.iterrows():
    Student_ID=row["Student_ID"]
    
    KONT=row["PAUNtÜRÜ"]
    row["sayı"]+=1
tercih_df
